# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from joblib import Parallel, delayed
import time
import pyarrow
import warnings
warnings.filterwarnings('ignore')

# %%
#driver configuration

opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
# opciones.add_argument('Cookies')    # mantiene las cookies
# opciones.add_extension('./Ad_Blocker/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
# Construcción de url's

countries = ['es','us','uk','au','de','ca','br','id',
             'nl','fr','tr','mx','se','it','ar','ie']

url = 'https://www.songkick.com/es/festivals/countries/'
url_countries = [url + c for c in countries]

# %%
PATH = ChromeDriverManager().install()     # instala el driver de chrome

# %%
# Función que devuelve un dataframe con los festivales y respectivas url's por cada país
def fest_country(url):
    driver=webdriver.Chrome(PATH,options=opciones)   
    driver.get(url)
    time.sleep(5)
    
    try:
        driver.find_element(By.ID,'onetrust-accept-btn-handler').click()  # Aceptar cookies
    except:
        pass
    time.sleep(4)
    fest_list = []

    for fest in driver.find_elements(By.XPATH,'//p[@class="artists summary"]//a'):
        temp = dict()
        temp['Festival'] = fest.text.split('\n')[0]
        temp['url'] = fest.get_property('href')
        fest_list.append(temp)

    return pd.DataFrame(fest_list)

# %%
paralelo = Parallel(n_jobs=6, verbose=True)

lst_df_fest = paralelo(delayed(fest_country)(url) for url in url_countries)
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  16 out of  16 | elapsed:  3.7min finished

# %%
df_fest = pd.concat(lst_df_fest)
df_fest = df_fest.reset_index(drop=True)
df_fest.tail()
# Out:
#                             Festival
# 385     INDIE-PENDANCE FESTIVAL 2023  \
# 386      Indiependence Festival 2023
# 387            All together Now 2023
# 388  Ballaghdream Arts festival 2023
# 389    Playing Fields Festivals 2023
#
#                                                    url
# 385  https://www.songkick.com/es/festivals/50496-in...
# 386  https://www.songkick.com/es/festivals/137571-i...
# 387  https://www.songkick.com/es/festivals/2236829-...
# 388  https://www.songkick.com/es/festivals/3540758-...
# 389  https://www.songkick.com/es/festivals/3551033-...

# %%
dod_fest = pd.read_csv('../data/Dod_fest.csv')
dod_fest
# Out:
#                                    Festival
# 0                           WAN 2023 Madrid
# 1                            Inverfest 2023
# 2                      Actual Festival 2023
# 3                         Microsonidos 2023
# 4                           Horteralia 2023
# ..                                      ...
# 255       Primavera Sound Buenos Aires 2023
# 256  Primavera Sound Santiago de Chile 2023
# 257                 Lollapalooza Chile 2023
# 258             Lollapalooza Argentina 2023
# 259                     Festival Nrmal 2021
#
# [260 rows x 1 columns]

# %%
url = 'https://www.songkick.com/es/search?utf8=%E2%9C%93&query='
dod_url = [url + f.replace(' ','+') for f in dod_fest.Festival]

# %%
def check_dod_fest(url):
    driver=webdriver.Chrome(PATH,options=opciones)   
    
    # Desactivar la extensión
     
    try:
        driver.get(url)
        time.sleep(4)
    except:
        return {'Festival':None,'url':None}
    
    temp = dict()
    temp['Festival'] = url.split('query=')[-1].replace('+',' ')
    
    
    try:
        driver.find_element(By.ID,'onetrust-accept-btn-handler').click()  # Aceptar cookies
    except:
        pass
    
    try:
        if driver.find_element(By.XPATH,'//div[@class="no-results"]') == []:  # Si es True, no hay registro en Songkick
            temp['url'] = None
            return temp
    except:
        pass
    
    try:
        if driver.find_element(By.XPATH,'/html/body/div[4]/div/div/div[2]/div/ul/li[1]/div[1]/span').text == 'FESTIVAL PASADO':
            temp['url'] = None
            return temp
        pass
    except:
        pass
    
    xpath = '/html/body/div[4]/div/div/div[2]/div/ul/li/div[1]'

    try:
        temp['url'] = driver.find_element(By.XPATH,xpath).find_element(By.XPATH,'//p[@class="summary"]//a').get_property('href') # url si existe
        return temp
    
    except:
        temp['url'] = None
        return temp

# %%
lst_dod_fest = paralelo(delayed(check_dod_fest)(url) for url in dod_url)
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=6)]: Done 260 out of 260 | elapsed: 22.2min finished

# %%
pd.DataFrame(lst_dod_fest).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Festival  260 non-null    object
#  1   url       128 non-null    object
# dtypes: object(2)
# memory usage: 4.2+ KB

# %%
dod_fest = pd.DataFrame(lst_dod_fest)
dod_fest.head()
# Out:
#                Festival                                                url
# 0       WAN 2023 Madrid                                               None
# 1        Inverfest 2023                                               None
# 2  Actual Festival 2023                                               None
# 3     Microsonidos 2023  https://www.songkick.com/es/concerts/40648056-...
# 4       Horteralia 2023                                               None

# %%
dod_fest = dod_fest[dod_fest.url.notna()]

# %%
pd.concat([df_fest,dod_fest],axis=0)[pd.concat([df_fest,dod_fest],axis=0).duplicated()]
# Out:
#                         Festival
# 20   Mallorca Live Festival 2023  \
# 37    Les Nits de Barcelona 2023
# 43     Azkena Rock Festival 2023
# 64        Resurrection Fest 2023
# 65   Rock Imperium Festival 2023
# 92          Bilbao BBK Live 2023
# 99        Mad Cool Festival 2023
# 223          Leeds Festival 2023
# 228            Lollapalooza 2023
# 237            Rock am Ring 2023
#
#                                                    url
# 20   https://www.songkick.com/es/festivals/1520684-...
# 37   https://www.songkick.com/es/festivals/3547261-...
# 43   https://www.songkick.com/es/festivals/1515-azk...
# 64   https://www.songkick.com/es/festivals/71471-re...
# 65   https://www.songkick.com/es/festivals/3373532-...
# 92   https://www.songkick.com/es/festivals/6331-bil...
# 99   https://www.songkick.com/es/festivals/1481913-...
# 223  https://www.songkick.com/es/festivals/58-leeds...
# 228  https://www.songkick.com/es/festivals/1235-lol...
# 237  https://www.songkick.com/es/festivals/1237-roc...

# %%
index_dup = pd.concat([df_fest,dod_fest],axis=0)[pd.concat([df_fest,dod_fest],axis=0)[['Festival','url']].duplicated()].index

# %%
dod_fest.loc[index_dup]
# Out:
#                         Festival
# 20   Mallorca Live Festival 2023  \
# 37    Les Nits de Barcelona 2023
# 43     Azkena Rock Festival 2023
# 64        Resurrection Fest 2023
# 65   Rock Imperium Festival 2023
# 92          Bilbao BBK Live 2023
# 99        Mad Cool Festival 2023
# 223          Leeds Festival 2023
# 228            Lollapalooza 2023
# 237            Rock am Ring 2023
#
#                                                    url
# 20   https://www.songkick.com/es/festivals/1520684-...
# 37   https://www.songkick.com/es/festivals/3547261-...
# 43   https://www.songkick.com/es/festivals/1515-azk...
# 64   https://www.songkick.com/es/festivals/71471-re...
# 65   https://www.songkick.com/es/festivals/3373532-...
# 92   https://www.songkick.com/es/festivals/6331-bil...
# 99   https://www.songkick.com/es/festivals/1481913-...
# 223  https://www.songkick.com/es/festivals/58-leeds...
# 228  https://www.songkick.com/es/festivals/1235-lol...
# 237  https://www.songkick.com/es/festivals/1237-roc...

# %%
dod_fest = dod_fest.drop(index=index_dup)
dod_fest = dod_fest.dropna().reset_index(drop=True)
dod_fest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Festival  118 non-null    object
#  1   url       118 non-null    object
# dtypes: object(2)
# memory usage: 2.0+ KB

# %%
df_fest = pd.concat([df_fest,dod_fest],axis=0).reset_index(drop=True)
df_fest
# Out:
#                                 Festival
# 0            Mallorca Live Festival 2023  \
# 1             Primavera a la Ciutat 2023
# 2    Primavera In The City - Madrid 2023
# 3          Primavera Sound Festival 2023
# 4                    Primavera Pack 2023
# ..                                   ...
# 503                       NOS Alive 2023
# 504       Primavera Sound São Paulo 2023
# 505                 Sziget Festival 2023
# 506                  Corona Capital 2023
# 507          Lollapalooza Argentina 2023
#
#                                                    url
# 0    https://www.songkick.com/es/festivals/1520684-...
# 1    https://www.songkick.com/es/festivals/3452756-...
# 2    https://www.songkick.com/es/festivals/3500869-...
# 3    https://www.songkick.com/es/festivals/618-prim...
# 4    https://www.songkick.com/es/festivals/3495900-...
# ..                                                 ...
# 503  https://www.songkick.com/es/festivals/1192678-...
# 504  https://www.songkick.com/es/festivals/3439946-...
# 505  https://www.songkick.com/es/festivals/608-szig...
# 506  https://www.songkick.com/es/festivals/106236-c...
# 507  https://www.songkick.com/es/concerts/40806204-...
#
# [508 rows x 2 columns]

# %%
def fest_detail(url):
    try:
        driver=webdriver.Chrome(PATH,options=opciones)   
        driver.get(url)
        time.sleep(4)
    except:
        new_cols = {'Cartel':None,'Date':None,'Location':None,'info':None}
        return new_cols
        
    try:
        driver.find_element(By.ID,
                            'onetrust-accept-btn-handler').click()  # Aceptar cookies
    except:
        pass
    time.sleep(2)
    
    try:
        cart = [artist.text for artist in driver.find_elements(By.XPATH,
                                                               '//ul[@class="festival"]//li')]  # Lista de artistas del festival
    except:
        cart = None
    try: 
        date = driver.find_element(By.XPATH,
                                   '//div[@class="date-and-name"]//p').text  # Fecha del festival
    except:
        date = None
    try:
        location = driver.find_element(By.XPATH,
                                       '//div[@class="venue-info-details"]//a').text # Localización del evento
    except:
        location = None
    try:
        info = driver.find_element(By.XPATH,
                                   '//div[@class="venue-info-details"]//p[@class="venue-hcard"]').text # Infirmación del lugar del evento
    except:
        info = None

    new_cols = {'Cartel':cart,'Date':date,'Location':location,'info':info}
    return new_cols

# %%
lst_new_cols = paralelo(delayed(fest_detail)(url) for url in df_fest.url)
# Out:
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed: 26.9min
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed: 60.9min
# [Parallel(n_jobs=6)]: Done 508 out of 508 | elapsed: 69.6min finished

# %%
df_fest = pd.concat([df_fest,pd.DataFrame(lst_new_cols)],axis=1)
df_fest.head()
# Out:
#                               Festival
# 0          Mallorca Live Festival 2023  \
# 1           Primavera a la Ciutat 2023
# 2  Primavera In The City - Madrid 2023
# 3        Primavera Sound Festival 2023
# 4                  Primavera Pack 2023
#
#                                                  url
# 0  https://www.songkick.com/es/festivals/1520684-...  \
# 1  https://www.songkick.com/es/festivals/3452756-...
# 2  https://www.songkick.com/es/festivals/3500869-...
# 3  https://www.songkick.com/es/festivals/618-prim...
# 4  https://www.songkick.com/es/festivals/3495900-...
#
#                                               Cartel
# 0  [Black Eyed Peas, Chemical Brothers, The Dandy...  \
# 1  [Jake Bugg, Pet Shop Boys, Confidence Man, La ...
# 2  [Bleachers, Julia Jacklin, PUP, Black Country,...
# 3  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...
# 4  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...
#
#                                            Date         Location
# 0     jueves 18 mayo 2023 – sábado 20 mayo 2023   Antic Aquapark  \
# 1  martes 30 mayo 2023 – miércoles 31 mayo 2023       Sala Apolo
# 2   lunes 05 junio 2023 – domingo 11 junio 2023             None
# 3  jueves 08 junio 2023 – domingo 11 junio 2023  Ciudad del Rock
# 4   jueves 08 junio 2023 – sábado 10 junio 2023  Ciudad del Rock
#
#                                                 info
# 0  Camí Cala Figuera, 1\n07181\nCalvia, Spain\nww...
# 1  C/ Nou De La Rambla 113\n08004\nBarcelona, Spa...
# 2                                               None
# 3  Autovía A3: Sentido Valencia Salida 33A, 35\n2...
# 4  Autovía A3: Sentido Valencia Salida 33A, 35\n2...

# %%
df_fest.to_parquet('../data/df_fest_raw.parquet',index=False,engine='pyarrow')

# %%
df_fest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Festival  508 non-null    object
#  1   url       508 non-null    object
#  2   Cartel    508 non-null    object
#  3   Date      508 non-null    object
#  4   Location  433 non-null    object
#  5   info      433 non-null    object
# dtypes: object(6)
# memory usage: 23.9+ KB

# %%
# Festivales cuyo cartel no está disponible en songkick.com

df_fest[df_fest.Cartel.notna()][df_fest[df_fest.Cartel.notna()]['Cartel'].apply(len) == 0]
# Out:
#                                               Festival
# 98                          P!NK: Summer Carnival 2024  \
# 99                          P!NK: Summer Carnival 2024
# 121                              Damage Done Fest 2023
# 263                         Konya Müzik Festivali 2023
# 309                                  Lollapalooza 2023
# 372               Doolin Folk Festival Early Bird 2023
# 381  Otherside Campervan(Must Hold Valid Weekend Fe...
# 390                                  Microsonidos 2023
# 392                               MUTEK Barcelona 2023
# 393                               Ressons Penedès 2023
# 394                                        L.E.V. 2023
# 402                             Off Week Festival 2023
# 408                    Noches del Botánico Madrid 2023
# 421                                    Marea Rock 2022
# 436         Concert Music Festival 2023 (Sancti Petri)
# 446                            Big Sound Festival 2023
# 448                                      Ezcafest 2023
# 452           Festival de Jazz de Vitoria-Gasteiz 2023
# 470                             Festival Noroeste 2022
# 472                                     Nocturama 2022
# 481                 BAM 2022 (Barcelona Acció Musical)
# 483                                     BIME Live 2023
# 485                 Sonorama Ribera goes to Ibiza 2022
# 486                               Iberia Festival 2022
# 487                                         Musgo 2022
# 488                                Purple Weekend 2022
# 504                     Primavera Sound São Paulo 2023
# 507                        Lollapalooza Argentina 2023
#
#                                                    url Cartel
# 98   https://www.songkick.com/es/festivals/3487862-...     []  \
# 99   https://www.songkick.com/es/festivals/3487862-...     []
# 121  https://www.songkick.com/es/festivals/3343435-...     []
# 263  https://www.songkick.com/es/festivals/3537027-...     []
# 309  https://www.songkick.com/es/festivals/1235-lol...     []
# 372  https://www.songkick.com/es/festivals/3456578-...     []
# 381  https://www.songkick.com/es/festivals/3514075-...     []
# 390  https://www.songkick.com/es/concerts/40648056-...     []
# 392  https://www.songkick.com/es/concerts/40977295-...     []
# 393  https://www.songkick.com/es/concerts/40927420-...     []
# 394  https://www.songkick.com/es/concerts/40873124-...     []
# 402  https://www.songkick.com/es/festivals/3532629-...     []
# 408  https://www.songkick.com/es/concerts/40965205-...     []
# 421  https://www.songkick.com/es/concerts/40342603-...     []
# 436  https://www.songkick.com/es/concerts/40898989-...     []
# 446  https://www.songkick.com/es/concerts/40989796-...     []
# 448  https://www.songkick.com/es/concerts/40771342-...     []
# 452  https://www.songkick.com/es/concerts/41014743-...     []
# 470  https://www.songkick.com/es/concerts/40526262-...     []
# 472  https://www.songkick.com/es/concerts/40669700-...     []
# 481  https://www.songkick.com/es/concerts/40609836-...     []
# 483  https://www.songkick.com/es/concerts/41087132-...     []
# 485  https://www.songkick.com/es/concerts/40672642-...     []
# 486  https://www.songkick.com/es/concerts/40675062-...     []
# 487  https://www.songkick.com/es/concerts/40712063-...     []
# 488  https://www.songkick.com/es/concerts/40691412-...     []
# 504  https://www.songkick.com/es/festivals/3439946-...     []
# 507  https://www.songkick.com/es/concerts/40806204-...     []
#
#                                                   Date
# 98                             viernes 23 febrero 2024  \
# 99                               viernes 01 marzo 2024
# 121                              sábado 26 agosto 2023
# 263       jueves 22 junio 2023 – domingo 25 junio 2023
# 309     miércoles 28 junio 2023 – sábado 01 julio 2023
# 372                              viernes 09 junio 2023
# 381      viernes 07 julio 2023 – domingo 09 julio 2023
# 390                            viernes 10 febrero 2023
# 392                              viernes 17 marzo 2023
# 393                              domingo 30 abril 2023
# 394                             sábado 18 febrero 2023
# 402                               sábado 17 junio 2023
# 408                               jueves 27 julio 2023
# 421                            miércoles 22 junio 2022
# 436                              viernes 07 julio 2023
# 446                               domingo 28 mayo 2023
# 448                              viernes 28 julio 2023
# 452                               sábado 08 julio 2023
# 470                           miércoles 10 agosto 2022
# 472                             sábado 15 octubre 2022
# 481                         domingo 25 septiembre 2022
# 483                                jueves 04 mayo 2023
# 485                             sábado 08 octubre 2022
# 486                           jueves 17 noviembre 2022
# 487                          viernes 04 noviembre 2022
# 488                          viernes 09 diciembre 2022
# 504  sábado 02 diciembre 2023 – domingo 03 diciembr...
# 507                               jueves 16 marzo 2023
#
#                                          Location
# 98                                           None  \
# 99                                  Optus Stadium
# 121                                      Uferpark
# 263                                          None
# 309                                        Gärdet
# 372                                  Hotel Doolin
# 381                                     Rock Farm
# 390                                  Microsonidos
# 392                    MUTEK Barcelona @Bridge_48
# 393                          Elyssia by Freixenet
# 394                                     Nato E.v.
# 402                               Hola Beach Club
# 408                           Noches del Botánico
# 421                               Sala Marea Rock
# 436           Concert Music Festival Sancti Petri
# 446                           Tahl Sound Festival
# 448                            Ezcafest (Ezcaray)
# 452  Festival De Jazz De Vitoria-Gasteiz (Teatro)
# 470                   FESTIVAL NOROESTE Galicia ,
# 472                                     Nocturama
# 481                                          None
# 483                                       Bonfire
# 485                 Sonorama Ribera goes to Ibiza
# 486                       Guimarães Jazz Festival
# 487                             Cafe & Pop Torgal
# 488                                          None
# 504       Autódromo José Carlos Pace (Interlagos)
# 507                                   Niceto Club
#
#                                                   info
# 98                                                None
# 99   333 Victoria Park Drive\n6100\nBurswood, WA, A...
# 121         Schlengendeich 21\n21107\nHamburg, Germany
# 263                                               None
# 309            Valhallavägen\n10252\nStockholm, Sweden
# 372                                     Clare, Ireland
# 381                           C15 FNP4\nSlane, Ireland
# 390                   Murcia, Spain\nwww.12ymedio.com/
# 392  Bridge_48 Carrer Llull, 48\n08005\nBarcelona, ...
# 393  Partida, Carrer de la Torre del Gall, s/n. San...
# 394  Karl-Liebknecht-Straße 46\n04275\nLeipzig, Ger...
# 402         cala vallcarca, C-31\n08871\nSitges, Spain
# 408  Real Jardín Botánico Alfonso XIII\n28040\nMadr...
# 421  Muelle de Levante, 6, Puerto Alicante, Alicant...
# 436                     Chiclana De La Frontera, Spain
# 446  302 Southland Dr\n40503\nLexington, KY, US\nww...
# 448                                    La Rioja, Spain
# 452  Teatro Principal Antzokia\n01007\nVitoria-Gast...
# 470                                   La Coruna, Spain
# 472                                     Seville, Spain
# 481                                               None
# 483               Av Caracas 72 A 19\nBogota, Colombia
# 485                                       Ibiza, Spain
# 486                Various Venues\nGuimaraes, Portugal
# 487  Celso Emilio Ferreiro, 20\n32004\nOurense, Spa...
# 488                                               None
# 504  Av. Senador Teotônio Vilela, 261\n04801-010\nS...
# 507  Av. Cnel. Niceto Vega 5510\nC1414BFD\nBuenos A...

# %%
index_empty_cartel = df_fest[df_fest.Cartel.notna()][df_fest[df_fest.Cartel.notna()]['Cartel'].apply(len) == 0].index

# %%
# Eliminamos filas de las que no podemos acceder al cartel

df_fest = df_fest.drop(index=index_empty_cartel)

# %%
df_fest = df_fest.reset_index(drop=True)

# %%
# Solo nos quedan nulos en Location e info
df_fest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Festival  480 non-null    object
#  1   url       480 non-null    object
#  2   Cartel    480 non-null    object
#  3   Date      480 non-null    object
#  4   Location  409 non-null    object
#  5   info      409 non-null    object
# dtypes: object(6)
# memory usage: 22.6+ KB

# %%
df_fest[(df_fest['info'].isna())|(df_fest['Location'].isna())]
# Out:
#                                 Festival
# 2    Primavera In The City - Madrid 2023  \
# 7                             Sonar 2023
# 13                    Vida Festival 2023
# 16   Brunch In the Park - Barcelona 2023
# 22                       Dreambeach 2023
# ..                                   ...
# 455                     Caudal Fest 2023
# 456                      Ebrovisión 2023
# 463            Glastonbury Festival 2023
# 468                   Rock en Seine 2023
# 471             Lollapalooza Berlín 2023
#
#                                                    url
# 2    https://www.songkick.com/es/festivals/3500869-...  \
# 7    https://www.songkick.com/es/festivals/1535-son...
# 13   https://www.songkick.com/es/festivals/739019-v...
# 16   https://www.songkick.com/es/festivals/3466699-...
# 22   https://www.songkick.com/es/festivals/697694-d...
# ..                                                 ...
# 455  https://www.songkick.com/es/festivals/2620959-...
# 456  https://www.songkick.com/es/festivals/358-ebro...
# 463  https://www.songkick.com/es/festivals/585-glas...
# 468  https://www.songkick.com/es/festivals/7031-roc...
# 471  https://www.songkick.com/es/festivals/1253513-...
#
#                                                 Cartel
# 2    [Bleachers, Julia Jacklin, PUP, Black Country,...  \
# 7    [Fever Ray, Bad Gyal, Richie Hawtin, Charlotte...
# 13   [The Libertines, AURORA, Julieta Venegas, Sued...
# 16                                       [Fatboy Slim]
# 22   [Armin van Buuren, The Prodigy, Carl Cox, Apas...
# ..                                                 ...
# 455  [Vetusta Morla, Leiva, La La Love You, Veintiu...
# 456                                [Mujeres, Karavana]
# 463  [Arctic Monkeys, Blondie, Rudimental, Lewis Ca...
# 468  [Billie Eilish, The Strokes, Florence + The Ma...
# 471  [Imagine Dragons, David Guetta, Jason Derulo, ...
#
#                                                   Date Location  info
# 2          lunes 05 junio 2023 – domingo 11 junio 2023     None  None
# 7          jueves 15 junio 2023 – sábado 17 junio 2023     None  None
# 13         jueves 29 junio 2023 – sábado 01 julio 2023     None  None
# 16                               domingo 02 julio 2023     None  None
# 22   miércoles 09 agosto 2023 – domingo 13 agosto 2023     None  None
# ..                                                 ...      ...   ...
# 455  viernes 15 septiembre 2023 – sábado 16 septiem...     None  None
# 456  jueves 31 agosto 2023 – domingo 03 septiembre ...     None  None
# 463    miércoles 21 junio 2023 – domingo 25 junio 2023     None  None
# 468  miércoles 23 agosto 2023 – domingo 27 agosto 2023     None  None
# 471  sábado 09 septiembre 2023 – domingo 10 septiem...     None  None
#
# [71 rows x 6 columns]

# %%
# Sustituímos por 'Unknown'

df_fest.fillna('Unknown',inplace= True)

# %%
df_fest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Festival  480 non-null    object
#  1   url       480 non-null    object
#  2   Cartel    480 non-null    object
#  3   Date      480 non-null    object
#  4   Location  480 non-null    object
#  5   info      480 non-null    object
# dtypes: object(6)
# memory usage: 22.6+ KB

# %% [markdown]
# Observamos que la estructura de la fecha es la siguiente:
# * Si tiene fecha de inicio y fecha de fin, vienen separadas por '-'
# * Parece que todas tienen estructura día de semana / día / mes / año.

# %% [markdown]
# Procederemos de la siguiente manera:
# 1. Crearemos columna fecha de inicio y fecha de fin
# 2. Si no tiene fecha de fin, esta sera igual a la fecha de inicio

# %%
# Creamos nuevas columnas y renombramos
df_fest.insert(loc=4,column='End_Date',value='')
df_fest.rename(columns={'Date':'Start_Date'},inplace=True)

# %%
def split_date(x):
    try:
        return x.split(' – ')[-1]  # OJO, es el caracter — (alt+0151) no el guión
    except:
        return x

# %%
df_fest['End_Date'] = df_fest['Start_Date'].apply(split_date)

# %%
df_fest.head()
# Out:
#                               Festival
# 0          Mallorca Live Festival 2023  \
# 1           Primavera a la Ciutat 2023
# 2  Primavera In The City - Madrid 2023
# 3        Primavera Sound Festival 2023
# 4                  Primavera Pack 2023
#
#                                                  url
# 0  https://www.songkick.com/es/festivals/1520684-...  \
# 1  https://www.songkick.com/es/festivals/3452756-...
# 2  https://www.songkick.com/es/festivals/3500869-...
# 3  https://www.songkick.com/es/festivals/618-prim...
# 4  https://www.songkick.com/es/festivals/3495900-...
#
#                                               Cartel
# 0  [Black Eyed Peas, Chemical Brothers, The Dandy...  \
# 1  [Jake Bugg, Pet Shop Boys, Confidence Man, La ...
# 2  [Bleachers, Julia Jacklin, PUP, Black Country,...
# 3  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...
# 4  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...
#
#                                      Start_Date                End_Date
# 0     jueves 18 mayo 2023 – sábado 20 mayo 2023     sábado 20 mayo 2023  \
# 1  martes 30 mayo 2023 – miércoles 31 mayo 2023  miércoles 31 mayo 2023
# 2   lunes 05 junio 2023 – domingo 11 junio 2023   domingo 11 junio 2023
# 3  jueves 08 junio 2023 – domingo 11 junio 2023   domingo 11 junio 2023
# 4   jueves 08 junio 2023 – sábado 10 junio 2023    sábado 10 junio 2023
#
#           Location                                               info
# 0   Antic Aquapark  Camí Cala Figuera, 1\n07181\nCalvia, Spain\nww...
# 1       Sala Apolo  C/ Nou De La Rambla 113\n08004\nBarcelona, Spa...
# 2          Unknown                                            Unknown
# 3  Ciudad del Rock  Autovía A3: Sentido Valencia Salida 33A, 35\n2...
# 4  Ciudad del Rock  Autovía A3: Sentido Valencia Salida 33A, 35\n2...

# %%
def split_start_date(x):
    try:
        return x.split(' – ')[0]  # OJO, es el caracter — (alt+0151) no el guión
    except:
        return x

# %%
df_fest['Start_Date'] = df_fest['Start_Date'].apply(split_start_date)

# %%
df_fest.head()
# Out:
#                               Festival
# 0          Mallorca Live Festival 2023  \
# 1           Primavera a la Ciutat 2023
# 2  Primavera In The City - Madrid 2023
# 3        Primavera Sound Festival 2023
# 4                  Primavera Pack 2023
#
#                                                  url
# 0  https://www.songkick.com/es/festivals/1520684-...  \
# 1  https://www.songkick.com/es/festivals/3452756-...
# 2  https://www.songkick.com/es/festivals/3500869-...
# 3  https://www.songkick.com/es/festivals/618-prim...
# 4  https://www.songkick.com/es/festivals/3495900-...
#
#                                               Cartel            Start_Date
# 0  [Black Eyed Peas, Chemical Brothers, The Dandy...   jueves 18 mayo 2023  \
# 1  [Jake Bugg, Pet Shop Boys, Confidence Man, La ...   martes 30 mayo 2023
# 2  [Bleachers, Julia Jacklin, PUP, Black Country,...   lunes 05 junio 2023
# 3  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...  jueves 08 junio 2023
# 4  [Kendrick Lamar, Calvin Harris, Skrillex, Hals...  jueves 08 junio 2023
#
#                  End_Date         Location
# 0     sábado 20 mayo 2023   Antic Aquapark  \
# 1  miércoles 31 mayo 2023       Sala Apolo
# 2   domingo 11 junio 2023          Unknown
# 3   domingo 11 junio 2023  Ciudad del Rock
# 4    sábado 10 junio 2023  Ciudad del Rock
#
#                                                 info
# 0  Camí Cala Figuera, 1\n07181\nCalvia, Spain\nww...
# 1  C/ Nou De La Rambla 113\n08004\nBarcelona, Spa...
# 2                                            Unknown
# 3  Autovía A3: Sentido Valencia Salida 33A, 35\n2...
# 4  Autovía A3: Sentido Valencia Salida 33A, 35\n2...

# %%
df_fest.to_parquet('../data/df_fest_clean.parquet',index=False,engine='pyarrow')

# %%
grupos = list(set([grupo for cartel in df_fest.Cartel for grupo in cartel]))

# %%
len (grupos)
# Out:
# 5174

# %%
pd.DataFrame({'Grupos':grupos}).to_csv('../data/grupos.csv',index=False)
